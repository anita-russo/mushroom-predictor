# %%
#          ___..._
#     _,--' )     "`-.    MUSHROOM
#   ,'.  .      (  )  \   CLASSIFICATION
#  /:. .     .         .  ALGORITHM
# |;..) .  (  )  _..--'
# `--:...-,-'""\          We use keras to determine the likelihood that a mushroom 
#         |:.  `.         is safe to eat based on given criteria. 
#         l;.   l         (For academic purposes only!)
#         `|:.   |
#          |:.   `.,      Anita Russo 
#         .l;.    j, ,    Christopher Hughes 
#      `. \`;:.   //,/    Matthew Geddes 
#       .\\)`;,|\'/(      Avery Cieszynski
#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part #1: Exploring the dataset

# %%
# Dataset from: https://www.kaggle.com/uciml/mushroom-classification
# class: e, p (edible, poisonous)

df = pd.read_csv("mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
# Columns are object type, will need to be converted to floating point values

df.columns.dtype
# Out:
# dtype('O')

# %%
# Are there any null values to remove? 

df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# We have 23 columns, but are they all useful for determining edibility? 

print("Number of columns: ", len(df.columns))
print("Number of rows: ", len(df))
# Out:
# Number of columns:  23
# Number of rows:  8124

# %% [markdown]
# ## Part #2: Graphing correlation between columns and edibility

# %%
# Check correlation between 'bruises' column and edibility

bruises_edible = len(df[df['bruises'].str.contains('t') & df['class'].str.contains('e')])
bruises_poisonous = len(df[df['bruises'].str.contains('t') & df['class'].str.contains('p')])
nonbruise_edible = len(df[df['bruises'].str.contains('f') & df['class'].str.contains('e')])
nonbruise_poisonous = len(df[df['bruises'].str.contains('f') & df['class'].str.contains('p')])

#plot in pie chart

labels = 'Edible', 'Poisonous'
sizes = [bruises_edible, bruises_poisonous]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', colors=('#4ee330','#a35091'), shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Bruising Mushrooms")

plt.show()

sizes = [nonbruise_edible, nonbruise_poisonous]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', colors=('#4ee330','#a35091'), shadow=True, startangle=90)
ax1.axis('equal')  
plt.title("Non-Bruising Mushrooms")

plt.show()

print("Non-bruising mushrooms are more likely to be poisonous, whereas bruising mushrooms are usually edible")
# Out:
# Non-bruising mushrooms are more likely to be poisonous, whereas bruising mushrooms are usually edible

# %%
# using the odor column

odors = df['odor'].value_counts()
print(odors)

edible = []  
poisonous = [] 

labels = ('none','foul','fishy','spicy','almond','anise','pungent','creosote','musty')
n_groups = len(labels)

#get value counts for each odor in list
num = odors.values.tolist()
#get the value in the rows
odor_labels = odors.axes[0].tolist()

for odor in odor_labels:
    #get number of values for each odor
    size = len(df[df['odor'] == odor].index)
    #get the number of edible values for each odor and append to list
    edibles = len(df[(df['odor'] == odor) & (df['class'] == 'e')].index)
    edible.append(edibles)
    #poisonous is the number of values minus values that are edible
    poisonous.append(size-edibles)
    
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.4

rects1 = plt.bar(index, edible, bar_width, color='#4ee330', label='Edible')
rects2 = plt.bar(index + bar_width, poisonous, bar_width, color='#a35091', label='Poisonous')

plt.xlabel('Odor')
plt.ylabel('Quantity')
plt.title('Edibility by Odor')

plt.xticks(index + bar_width / 2, labels, fontsize=12)

plt.legend()
fig.autofmt_xdate()

plt.tight_layout()

plt.show()

print("From the above, we can see:")
print("None, almond and anise are likely to be edible")
print("Foul, fishy, spicy, pungent, creosote and musty are likely to be poisonous")
# Out:
# n    3528
# f    2160
# y     576
# s     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
# From the above, we can see:
# None, almond and anise are likely to be edible
# Foul, fishy, spicy, pungent, creosote and musty are likely to be poisonous

# %% [markdown]
# ## Part #3: Training the Neural Network

# %%
# drop the class column that we want to predict
X=df.drop('class',axis=1) 
y=df['class']
X.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
# 3         n          n           e  ...                        s
# 4         b          k           t  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 22 columns]

# %%
#e for edible, p for poisonous
y
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object

# %%
# prepare data by converting to numerical values
from sklearn.preprocessing import LabelEncoder
Encoder_X = LabelEncoder() 
for col in X.columns:
    X[col] = Encoder_X.fit_transform(X[col])
Encoder_y=LabelEncoder()
y = Encoder_y.fit_transform(y)

X.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         2                       7                       7
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0          0           2            1          4                  2
# 1          0           2            1          4                  3
# 2          0           2            1          4                  3
# 3          0           2            1          4                  2
# 4          0           2            1          0                  3
#
#    population  habitat
# 0           3        5
# 1           2        1
# 2           2        3
# 3           3        5
# 4           0        1
#
# [5 rows x 22 columns]

# %%
#e=0, p=1

y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential 
from keras.layers import Dense 

from sklearn.model_selection import train_test_split

#split data into training and testing
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Using TensorFlow backend.
# (6499, 22)
# (1625, 22)
# (6499,)
# (1625,)

# %%
#build a classifier 
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

classifier = KerasClassifier(build_fn=build_classifier, epochs=30, batch_size=2)
accuracies = cross_val_score(estimator=classifier,X=x_train,y=y_train, cv=3)
mean = accuracies.mean()
variance = accuracies.std()
# Out:
# Epoch 1/30
# 4332/4332 [==============================] - 4s 924us/step - loss: 0.3629 - accuracy: 0.8479
# Epoch 2/30
# 4332/4332 [==============================] - 4s 830us/step - loss: 0.2333 - accuracy: 0.9266
# Epoch 3/30
# 4332/4332 [==============================] - 3s 806us/step - loss: 0.2202 - accuracy: 0.9328
# Epoch 4/30
# 4332/4332 [==============================] - 4s 1ms/step - loss: 0.2092 - accuracy: 0.9372
# Epoch 5/30
# 4332/4332 [==============================] - 4s 821us/step - loss: 0.1992 - accuracy: 0.9409
# Epoch 6/30
# 4332/4332 [==============================] - 4s 889us/step - loss: 0.1935 - accuracy: 0.9404
# Epoch 7/30
# 4332/4332 [==============================] - 4s 1ms/step - loss: 0.1929 - accuracy: 0.9393
# Epoch 8/30
# 4332/4332 [==============================] - 4s 902us/step - loss: 0.1855 - accuracy: 0.9481
# Epoch 9/30
# 4332/4332 [==============================] - 5s 1ms/step - loss: 0.1835 - accuracy: 0.9458
# Epoch 10/30
# 4332/4332 [==============================] - 4s 925us/step - loss: 0.1835 - accuracy: 0.9439
# Epoch 11/30
# 4332/4332 [==============================] - 4s 863us/step - loss: 0.1767 - accuracy: 0.9492
# Epoch 12/30
# 4332/4332 [==============================] - 5s 1ms/step - loss: 0.1748 - accuracy: 0.9483
# Epoch 13/30
# 4332/4332 [==============================] - 4s 815us/step - loss: 0.1725 - accuracy: 0.9471
# Epoch 14/30
# 4332/4332 [==============================] - 4s 873us/step - loss: 0.1705 - accuracy: 0.9497
# Epoch 15/30
# 4332/4332 [==============================] - 4s 838us/step - loss: 0.1724 - accuracy: 0.9501
# Epoch 16/30
# 4332/4332 [==============================] - 3s 799us/step - loss: 0.1656 - accuracy: 0.9550
# Epoch 17/30
# 4332/4332 [==============================] - 4s 931us/step - loss: 0.1648 - accuracy: 0.9573
# Epoch 18/30
# 4332/4332 [==============================] - 4s 820us/step - loss: 0.1616 - accuracy: 0.9550
# Epoch 19/30
# 4332/4332 [==============================] - 4s 825us/step - loss: 0.1615 - accuracy: 0.9564
# Epoch 20/30
# 4332/4332 [==============================] - 5s 1ms/step - loss: 0.1611 - accuracy: 0.9589
# Epoch 21/30
# 4332/4332 [==============================] - 3s 808us/step - loss: 0.1597 - accuracy: 0.9591
# Epoch 22/30
# 4332/4332 [==============================] - 4s 1ms/step - loss: 0.1591 - accuracy: 0.9580: 0s -
# Epoch 23/30
# 4333/4333 [==============================] - 3s 793us/step - loss: 0.0218 - accuracy: 0.9922
# Epoch 22/30
# 4333/4333 [==============================] - 4s 835us/step - loss: 0.0252 - accuracy: 0.9919
# Epoch 23/30
# 4333/4333 [==============================] - 4s 871us/step - loss: 0.0191 - accuracy: 0.9933
# Epoch 24/30
# 4333/4333 [==============================] - 3s 802us/step - loss: 0.0156 - accuracy: 0.9956
# Epoch 25/30
# 4333/4333 [==============================] - 4s 842us/step - loss: 0.0235 - accuracy: 0.9919
# Epoch 26/30
# 4333/4333 [==============================] - 4s 874us/step - loss: 0.0183 - accuracy: 0.9935
# Epoch 27/30
# 4333/4333 [==============================] - 3s 790us/step - loss: 0.0150 - accuracy: 0.9949
# Epoch 28/30
# 4333/4333 [==============================] - 4s 839us/step - loss: 0.0165 - accuracy: 0.9938
# Epoch 29/30
# 4333/4333 [==============================] - 4s 860us/step - loss: 0.0130 - accuracy: 0.9954
# Epoch 30/30
# 4333/4333 [==============================] - 3s 796us/step - loss: 0.0196 - accuracy: 0.9940
# 2166/2166 [==============================] - 1s 328us/step

# %%
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Accuracy mean: 0.9903085430463155
# Accuracy variance: 0.01090048818253917

# %%
history = classifier.fit(x_test, y_test, validation_split=0.20, epochs=30, batch_size=2, verbose=1)
# Out:
# Train on 1300 samples, validate on 325 samples
# Epoch 1/30
# 1300/1300 [==============================] - 2s 2ms/step - loss: 0.5650 - accuracy: 0.7185 - val_loss: 0.3996 - val_accuracy: 0.8738
# Epoch 2/30
# 1300/1300 [==============================] - 2s 1ms/step - loss: 0.3310 - accuracy: 0.8746 - val_loss: 0.3204 - val_accuracy: 0.8892
# Epoch 3/30
# 1300/1300 [==============================] - 1s 1ms/step - loss: 0.2769 - accuracy: 0.9062 - val_loss: 0.2886 - val_accuracy: 0.8954
# Epoch 4/30
# 1300/1300 [==============================] - 1s 960us/step - loss: 0.2489 - accuracy: 0.9177 - val_loss: 0.3110 - val_accuracy: 0.9015
# Epoch 5/30
# 1300/1300 [==============================] - 1s 1ms/step - loss: 0.2320 - accuracy: 0.9292 - val_loss: 0.2587 - val_accuracy: 0.9046
# Epoch 6/30
# 1300/1300 [==============================] - 2s 1ms/step - loss: 0.2175 - accuracy: 0.9300 - val_loss: 0.2475 - val_accuracy: 0.9077
# Epoch 7/30
# 1300/1300 [==============================] - 2s 1ms/step - loss: 0.2052 - accuracy: 0.9308 - val_loss: 0.2451 - val_accuracy: 0.9077
# Epoch 8/30
# 1300/1300 [==============================] - 2s 1ms/step - loss: 0.1989 - accuracy: 0.9362 - val_loss: 0.2406 - val_accuracy: 0.9077
# Epoch 9/30
# 1300/1300 [==============================] - 1s 1ms/step - loss: 0.1922 - accuracy: 0.9377 - val_loss: 0.2271 - val_accuracy: 0.9169
# Epoch 10/30
# 1300/1300 [==============================] - 1s 1ms/step - loss: 0.1773 - accuracy: 0.9438 - val_loss: 0.2428 - val_accuracy: 0.9323
# Epoch 11/30
# 1300/1300 [==============================] - 2s 1ms/step - loss: 0.1751 - accuracy: 0.9423 - val_loss: 0.2189 - val_accuracy: 0.9231
